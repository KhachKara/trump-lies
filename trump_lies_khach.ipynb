# %%
import requests
r = requests.get('http://study-khach.xyz/portfolio/')

# %%
# print the first 500 characters of the HTML
print(r.text[:])
# Out:
# ï»¿<!DOCTYPE html>
# <html>
# <title>Ð ÐµÐ·ÑÐ¼Ðµ</title>
# <meta charset="UTF-8">
# <meta name="keywords" content="ÑÑÐ°Ð¶Ð¸ÑÐ¾Ð²ÐºÐ°, Ð¿ÑÐ°ÐºÑÐ¸ÐºÐ°, ÑÐ½Ð¸Ð¾Ñ ÑÐ°Ð·ÑÐ°Ð±Ð¾ÑÑÐ¸Ðº">
# <meta name="description" content="Ð®Ð½Ð¸Ð¾Ñ ÑÐ°Ð·ÑÐ°Ð±Ð¾ÑÑÐ¸Ðº Python / Django">
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <link rel="icon" href="img/khach.jpg">
# <link rel="stylesheet" href="css/w3.css">
# <link rel='stylesheet' href='https://fonts.googleapis.com/css?family=Roboto'>
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">
# <style>
#     html, body, h1, h2, h3, h4, h5, h6 {
#         font-family: "Roboto", sans-serif
#     }
# </style>
# <body class="w3-light-grey">
#
# <!-- Page Container -->
#     <div class="w3-content w3-margin-top" style="max-width:1400px;">
#
#     <!-- The Grid -->
#     <div class="w3-row-padding">
#
#         <!-- Left Column -->
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(r.text, 'html.parser')

# %%
results = soup.find_all('span')

# %%
results
# Out:
# [<span><a href="index.html">Ð ÑÑ</a></span>,
#  <span><a href="en.html">Eng</a></span>,
#  <span>Ð Ð¾Ð´Ð½Ð¾Ð¹</span>,
#  <span>Ð¡Ð²Ð¾Ð±Ð¾Ð´Ð½Ð¾ Ð²Ð»Ð°Ð´ÐµÑ</span>,
#  <span>ÐÐ¾Ð³Ñ Ð¿ÑÐ¾Ñ
#  Ð¾Ð´Ð¸ÑÑ Ð¸Ð½ÑÐµÑÐ²ÑÑ</span>,
#  <span><a href="index.html">Ð ÑÑ</a></span>,
#  <span><a href="en.html">Eng</a></span>,
#  <span class="w3-tag w3-teal w3-round">Ð¿Ð¾ ÑÐµÐ¹ Ð´ÐµÐ½Ñ</span>,
#  <span class="w3-tag w3-teal w3-round">Ð¾ÐºÐ¾Ð½ÑÐ°Ð½Ð¸Ðµ ÑÑÐµÐ±Ñ 2018</span>,
#  <span class="w3-tag w3-teal w3-round"> ÐÐ¸Ð´ÐµÐ¾ÐºÑÑÑ </span>]
